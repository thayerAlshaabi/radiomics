# %% [markdown]
# # Feature Analysis - Random Forest

# %% [markdown]
# ### Import required libraries

# %%
import sys, os
import itertools
import pandas as pd
import numpy as np
from scipy import stats

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import roc_curve, auc, confusion_matrix
from sklearn.utils import resample

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
def progressBar(value, endvalue, bar_length=50):
    percent = float(value) / endvalue
    arrow = '=' * int(round(percent * bar_length)-1) + '>'
    spaces = ' ' * (bar_length - len(arrow))

    sys.stdout.write("\r[{0}] {1}%".format(arrow + spaces, int(round(percent * 100))))

# %% [markdown]
# ### Import Data

# %%
data = pd.read_csv(os.path.join(os.path.abspath(os.pardir), 'src/dataset', 'data_101718.csv'), low_memory=False)

# %%
data.head()
# Out:
#       pid     xnorm      ynorm      znorm  cardistnorm  ca  voxelcount0i  \
# 0  129381 -40.78346  -8.199849  29.363550     50.91901   0          10.0
# 1  100676 -53.82082 -38.156560  -3.371359     66.06035   0         351.0
# 2  132772  49.27720 -35.530340  -1.662529     60.77345   0          18.0
# 3  126967  21.59079  15.484310  27.472460     38.21861   1        1374.0
# 4  102562  80.64488  16.086080 -69.602640    107.73530   0         173.0
#
#    graylevels0i     energy0i    entropy0i           ...             srlgle15c  \
# 0          10.0    2221248.0     0.000000           ...              0.000351
# 1         260.0  176300000.0   200.078200           ...              0.023536
# 2          18.0    2805381.0     0.000000           ...              0.000159
# 3         625.0  135400000.0  1900.617600           ...              0.005102
# 4         159.0   46611581.0    28.754888           ...              0.000151
#
#     srhgle15c  lrlgle15c   lrhgle15c  extrudedsurfacearea15c  \
# 0   17872.487   0.000949   42115.337               4760376.9
# 1   13326.403   0.107683   45091.633               6061283.1
# 2   54901.246   0.000356  174473.340               6801351.9
# 3   37566.835   0.012797  163982.200               6179906.4
# 4  210927.090   0.000230  671420.660               8901488.9
#
#    extrudedvolume15c  extrudedsurfacevolumeratio15c  boxcountingdimension15c  \
# 0         10073969.0                       0.472542                 2.091545
# 1         10260464.0                       0.590742                 2.065475
# 2         11157162.0                       0.609595                 2.189789
# 3          9170642.1                       0.673879                 2.145406
# 4          8746977.7                       1.017664                 2.117663
#
#    informationdimension15c  correlationdimension15c
# 0                 2.098287               -74.249922
# 1                 2.089445               -73.135671
# 2                 2.194593               -78.016611
# 3                -0.061130               -76.017566
# 4                -0.058523               -74.898571
#
# [5 rows x 274 columns]

# %%
data.shape
# Out:
# (3701, 274)

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# Let's take a look at the missing data, and try to figure our the best way to clean up our data.

# %% [markdown]
# Drop out the columns that have over 90% missing data points.

# %%
df = data.dropna(thresh=len(data)*.90, axis=1)

# %% [markdown]
# Drop out any rows that are missing more than 50% of the required columns

# %%
df = df.dropna(thresh=df.shape[1]*.5)

# %% [markdown]
# Drop out any rows that are missing the target value

# %%
df = df.dropna(axis=1, subset=df['ca'])

# %% [markdown]
# Fill the rest of missing entries with the mean of each col

# %%
df = df.apply(lambda col: col.fillna(col.mean()))

# %%
df.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ### Data Exploration

# %%
cor_mat = df.corr(method='pearson')
fig, ax =plt.subplots(figsize=(20, 15))
plt.title("Correlation Matrix")
sns.heatmap(
    cor_mat, mask=np.zeros_like(cor_mat, dtype=np.bool), 
    cmap=sns.diverging_palette(220, 10, as_cmap=True)
)

# %%
features = list(df.columns.values)
features.remove('pid')
features.remove('ca')

# %% [markdown]
# Let's balance out the pos and neg samples in the dataset

# %%
df_neg = df[df.ca==0]
df_pos = df[df.ca==1]

# %% [markdown]
# Upsample the pos samples

# %%
df_pos_upsampled = resample(
    df_pos,
    n_samples=len(df_neg),
    replace=True, 
    random_state=2018
)
df_upsampled = pd.concat([df_pos_upsampled, df_neg])

# %% [markdown]
# Downsample the neg samples

# %%
df_neg_downsampled = resample(
    df_neg,
    n_samples=len(df_pos),
    replace=True, 
    random_state=2018
)
df_downsampled = pd.concat([df_pos, df_neg_downsampled])

# %%
fig, axes = plt.subplots(figsize=(15,5), nrows=1, ncols=3)
df.ca.value_counts().plot.bar(ax=axes[0], rot=False, title='Original Distribution', color=['g','r'])
df_upsampled.ca.value_counts().plot.bar(ax=axes[1], rot=False, title='w/ Upsampling', color=['r','g'])
df_downsampled.ca.value_counts().plot.bar(ax=axes[2], rot=False, title='w/ Downsampling', color=['r','g'])

# %% [markdown]
# ### Setup Classifier

# %% [markdown]
# Normalize Data

# %%
# original distribution
#X = StandardScaler().fit_transform(df[features])
#y = df.ca.values

# w/upsampling
#X = StandardScaler().fit_transform(df_upsampled[features])
#y = df_upsampled.ca.values

# w/downsampling
X = StandardScaler().fit_transform(df_downsampled[features])
y = df_downsampled.ca.values

# %% [markdown]
# Specify parameters to test

# %%
rfc=RandomForestClassifier(random_state=2018)
param_grid = { 
    'n_estimators': [100, 300, 500],
    'max_features': ['auto', 'sqrt'],
    'criterion'   : ['gini', 'entropy'],
    'class_weight': ['balanced', 'balanced_subsample'],
}

# %% [markdown]
# Find the best parameters with GridSearchCV for (parallel 5 folds cross-validation)

# %%
# %%time
optimizer = GridSearchCV(
    rfc, param_grid=param_grid, cv=5, 
    scoring='roc_auc', verbose=10, n_jobs=-1
).fit(X, y)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100, score=0.9016003460207611, total=   0.7s
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100, score=0.8609935397638673, total=   0.7s
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100, score=0.8538650033415016, total=   0.7s
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100, score=0.8095344174649143, total=   0.7s
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=100, score=0.8921808866117175, total=   0.7s
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300, score=0.9075475778546713, total=   2.1s
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300, score=0.8692359100022278, total=   2.1s
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500
# [CV] class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300, score=0.8632212073958565, total=   2.1s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300, score=0.8204499888616619, total=   2.1s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=300, score=0.8964134551124971, total=   2.1s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100, score=0.9016003460207611, total=   0.7s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    2.9s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8609935397638673, total=   0.7s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8538650033415016, total=   0.7s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8095344174649143, total=   0.7s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8921808866117175, total=   0.7s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500, score=0.8696814435286255, total=   3.5s
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500, score=0.9096020761245676, total=   3.5s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500, score=0.8646691913566497, total=   3.5s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    4.5s
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500, score=0.8249053241256405, total=   3.5s
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300, score=0.9075475778546713, total=   2.2s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=gini, max_features=auto, n_estimators=500, score=0.8981955892180886, total=   3.6s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300, score=0.8692359100022278, total=   2.2s
# [CV] class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300, score=0.8632212073958565, total=   2.2s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300, score=0.8204499888616619, total=   2.2s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=300, score=0.8964134551124971, total=   2.2s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    6.7s
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100, score=0.9167387543252595, total=   0.9s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100, score=0.8671196257518379, total=   1.0s
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100, score=0.8782579639117843, total=   1.0s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500, score=0.9096020761245676, total=   3.6s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100, score=0.8168857206504789, total=   0.9s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=100, score=0.8927378035197149, total=   1.0s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500, score=0.8646691913566497, total=   3.7s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500, score=0.8249053241256405, total=   3.7s
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500, score=0.8696814435286255, total=   3.8s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced, criterion=gini, max_features=sqrt, n_estimators=500, score=0.8981955892180886, total=   3.7s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    9.8s
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300, score=0.922037197231834, total=   2.9s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300, score=0.8701269770550233, total=   2.9s
# [CV] class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300, score=0.8770327467141902, total=   2.9s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300, score=0.8242370238360436, total=   2.9s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.9167387543252595, total=   1.0s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.8671196257518379, total=   1.0s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=300, score=0.9073290265092447, total=   3.0s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.8168857206504789, total=   1.0s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.8782579639117843, total=   1.1s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.8927378035197149, total=   1.1s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:   14.0s
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500, score=0.8694586767654265, total=   5.3s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500, score=0.8762530630429939, total=   5.3s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500, score=0.9209558823529411, total=   5.4s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500, score=0.8233459567832481, total=   5.5s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=auto, n_estimators=500, score=0.9073290265092447, total=   5.6s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.922037197231834, total=   3.6s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.8701269770550233, total=   3.7s
# [CV] class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.8770327467141902, total=   3.7s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100, score=0.8994377162629759, total=   1.0s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.8242370238360436, total=   3.4s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.9073290265092447, total=   3.5s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   19.0s
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100, score=0.8608821563822677, total=   1.0s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100, score=0.8497438182223213, total=   1.0s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100, score=0.8130986856760972, total=   1.0s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=100, score=0.8914012029405213, total=   0.9s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.9209558823529411, total=   5.8s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.8694586767654265, total=   5.6s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.8762530630429939, total=   5.5s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300, score=0.9089532871972317, total=   2.8s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300, score=0.869570060147026, total=   2.8s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.8233459567832481, total=   5.5s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.9073290265092447, total=   5.5s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300, score=0.8625529071062596, total=   2.7s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300, score=0.8212296725328582, total=   2.8s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:   24.3s
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8994377162629759, total=   1.1s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=300, score=0.8981955892180886, total=   2.8s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8608821563822677, total=   0.9s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8497438182223213, total=   0.9s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8130986856760972, total=   0.9s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=100, score=0.8914012029405213, total=   0.9s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500, score=0.9103589965397925, total=   4.6s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500, score=0.8693472933838272, total=   4.6s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500, score=0.8607707730006683, total=   4.6s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500, score=0.8275785252840276, total=   4.5s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=auto, n_estimators=500, score=0.9000891067052796, total=   4.5s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300, score=0.9089532871972317, total=   2.7s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300, score=0.869570060147026, total=   2.6s
# [CV] class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:   28.6s
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300, score=0.8625529071062596, total=   2.6s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100, score=0.9185769896193772, total=   1.3s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300, score=0.8981955892180886, total=   2.7s
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=300, score=0.8212296725328582, total=   2.8s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100, score=0.8609935397638674, total=   1.2s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100, score=0.874805079082201, total=   1.2s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100, score=0.8215638226776565, total=   1.1s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500, score=0.9103589965397925, total=   4.6s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500, score=0.8693472933838272, total=   4.7s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=100, score=0.8970817554020941, total=   1.2s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500, score=0.8607707730006683, total=   4.8s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500, score=0.8275785252840276, total=   4.7s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=gini, max_features=sqrt, n_estimators=500, score=0.9000891067052796, total=   4.7s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300, score=0.9208477508650519, total=   3.4s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300, score=0.8660057919358431, total=   3.5s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed:   35.1s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300, score=0.8756961461349967, total=   3.4s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300, score=0.8267988416128313, total=   3.3s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=300, score=0.9025395411004679, total=   3.4s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.9185769896193772, total=   1.2s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.8609935397638674, total=   1.2s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.874805079082201, total=   1.2s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.8215638226776565, total=   1.1s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=100, score=0.8970817554020941, total=   1.1s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500, score=0.9209558823529412, total=   5.7s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500, score=0.8773668968589886, total=   5.5s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500, score=0.8651147248830474, total=   5.8s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500, score=0.824571173980842, total=   5.5s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.9208477508650519, total=   3.2s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=auto, n_estimators=500, score=0.9012029405212743, total=   5.6s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.8660057919358431, total=   3.3s
# [CV] class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.8756961461349967, total=   3.2s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.8267988416128313, total=   3.2s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=300, score=0.9025395411004679, total=   3.2s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.9209558823529412, total=   4.9s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.8773668968589886, total=   4.4s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.8651147248830474, total=   4.5s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.824571173980842, total=   4.3s
# [Parallel(n_jobs=-1)]: Done 118 out of 120 | elapsed:   45.2s remaining:    0.8s
# [CV]  class_weight=balanced_subsample, criterion=entropy, max_features=sqrt, n_estimators=500, score=0.9012029405212743, total=   4.0s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:   45.6s finished
# CPU times: user 2.71 s, sys: 264 ms, total: 2.97 s
# Wall time: 47.7 s

# %%
optimizer.best_params_
# Out:
# {'class_weight': 'balanced',
#  'criterion': 'entropy',
#  'max_features': 'auto',
#  'n_estimators': 300}

# %% [markdown]
# ### Benchmark

# %% [markdown]
# Run classifier with cross-validation and claculate the accuracy of the model based on True-Positive and False-Positive predictions

# %%
n_splits = 10
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=2018).split(X, y)
classifier = RandomForestClassifier(**optimizer.best_params_)

tprs, aucs = [], []
mean_fpr = np.linspace(0, 1, 100)
plt.figure(figsize=(10,8))

for itr, (train, test) in enumerate(cv):
    progressBar(itr+1, n_splits) 
    
    # get predictions
    probs = classifier.fit(X[train], y[train]).predict_proba(X[test])
    
    # compute AUC
    fpr, tpr, thresholds = roc_curve(y[test], probs[:, 1])
    tprs.append(np.interp(mean_fpr, fpr, tpr))
    tprs[-1][0] = 0.0
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)
    plt.plot(
        fpr, tpr, lw=1, alpha=0.5,
        label='ROC fold %d (AUC = %0.2f)' % (itr+1, roc_auc)
    )

# plot avg AUC    
mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
mean_auc = auc(mean_fpr, mean_tpr)
std_auc = np.std(aucs)
plt.plot(
    mean_fpr, mean_tpr, color='k',
    label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc)
)

# plot std
std_tpr = np.std(tprs, axis=0)
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
plt.fill_between(
    mean_fpr, tprs_lower, tprs_upper,
    color='grey', alpha=.2, label=r'$\pm$ std.'
)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title('ROC Curve', fontsize=20)
plt.legend(loc="lower right", fontsize=14)
plt.show()
# Out:
# [=================================================>] 100%

# %%
n_splits = 4
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=2018).split(X, y)
classifier = RandomForestClassifier(**optimizer.best_params_)
classes = df.ca.unique()

fig = plt.figure(figsize=(10,8))
for itr, (train, test) in enumerate(cv):
    progressBar(itr+1, n_splits) 
        
    # get predictions
    y_pred = classifier.fit(X[train], y[train]).predict(X[test])
    
    # compute confusion matrix
    matrix = confusion_matrix(y[test], y_pred)
    
    # plot confusion matrix
    ax = fig.add_subplot(2,2,itr+1)
    ax.imshow(matrix, interpolation='nearest', cmap=plt.cm.GnBu)
    
    for i, j in itertools.product(range(matrix.shape[0]), range(matrix.shape[1])):
        plt.text(
            j, i, format(matrix[i, j], 'd'),
            horizontalalignment="center",
            fontsize=14, color="white" if matrix[i, j] > matrix.max()/2 else "black"
        )
    
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)
    plt.ylabel('True label', fontsize=18)
    plt.xlabel('Predicted label', fontsize=18)
    plt.title('Fold %d' % (itr+1), fontsize=20)

plt.tight_layout()
# Out:
# [=================================================>] 100%

# %% [markdown]
# Plot Importance Score by Feature

# %%
importances = zip(features, map(lambda x: round(x, 2), classifier.feature_importances_))
scores = pd.DataFrame([list(score) for score in importances], 
    columns=['Feature', 'Importance Score']).sort_values(by='Importance Score', ascending=False)

# %%
scores.head(50)
# Out:
#                          Feature  Importance Score
# 35                clustershade0i              0.02
# 58                       hglre0i              0.02
# 60                      srhgle0i              0.02
# 51                varianceglcm0i              0.02
# 36             clustertendency0i              0.02
# 2                          znorm              0.02
# 37                    contrast0i              0.01
# 39               dissimilarity0i              0.01
# 48                  sumaverage0i              0.01
# 50                 sumvariance0i              0.01
# 216                  variance15c              0.01
# 57                       lglre0i              0.01
# 59                      srlgle0i              0.01
# 62                      lrhgle0i              0.01
# 67        informationdimension0i              0.01
# 227         maximum3ddiameter15c              0.01
# 223            surfaceareamm215c              0.01
# 0                          xnorm              0.01
# 34           clusterprominence0i              0.01
# 213  ventilationheterogeneity15c              0.01
# 210             meandeviation15c              0.01
# 91             surfaceareamm210b              0.01
# 93               compactness110b              0.01
# 98            autocorrelation10b              0.01
# 101           clustertendency10b              0.01
# 196       extrudedsurfacearea15b              0.01
# 192                    srlgle15b              0.01
# 186                       lre15b              0.01
# 118              varianceglcm10b              0.01
# 119                       sre10b              0.01
# 130       extrudedsurfacearea10b              0.01
# 147  ventilationheterogeneity15b              0.01
# 81   ventilationheterogeneity10b              0.01
# 152                laa950perc15b              0.01
# 33             autocorrelation0i              0.01
# 28                compactness10i              0.01
# 10               meanintensity0i              0.01
# 262       extrudedsurfacearea15c              0.01
# 9             maximumintensity0i              0.01
# 14              rootmeansquare0i              0.01
# 8             minimumintensity0i              0.01
# 17                    skewness0i              0.01
# 5                   graylevels0i              0.01
# 23                  laa856perc0i              0.01
# 25                    volumecc0i              0.01
# 11             medianintensity0i              0.01
# 31      sphericaldisproportion0i              0.01
# 3                    cardistnorm              0.01
# 162    sphericaldisproportion15b              0.00
# 193                    srhgle15b              0.00

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=scores[1:15], x='Importance Score', y='Feature', palette='GnBu_d')
plt.xticks(rotation=45, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Feature', fontsize=18)
plt.ylabel('Importance Score', fontsize=18)
plt.title('Importance Score per Feature', fontsize=30, y=1.05)
# Out:
# Text(0.5,1.05,'Importance Score per Feature')
